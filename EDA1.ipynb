# %%
import pandas as pd

# %%
k=pd.read_csv("quikr_car.csv")
k
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %%
k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
k.describe()
# Out:
#               name company  year          Price  kms_driven fuel_type
# count          892     892   892            892         840       837
# unique         525      48    61            274         258         3
# top     Honda City  Maruti  2015  Ask For Price  45,000 kms    Petrol
# freq            13     235   117             35          30       440

# %%
k.isnull().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    52
# fuel_type     55
# dtype: int64

# %%
k['Price']=k['Price'].astype('str')
k['Price']=k['Price'].str.replace(',',"")
k['Price']
# Out:
# 0              80000
# 1             425000
# 2      Ask For Price
# 3             325000
# 4             575000
#            ...
# 887           310000
# 888           260000
# 889           390000
# 890           180000
# 891           160000
# Name: Price, Length: 892, dtype: object

# %%
k=k[k['Price']!='Ask For Price']
k
# Out:
#                                        name    company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014  575000
# 6                                 Ford Figo       Ford  2012  175000
# ..                                      ...        ...   ...     ...
# 887                                      Ta       Tara  zest  310000
# 888                     Tata Zest XM Diesel       Tata  2018  260000
# 889                      Mahindra Quanto C8   Mahindra  2013  390000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014  180000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014  160000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# 1        40 kms    Diesel
# 3    28,000 kms    Petrol
# 4    36,000 kms    Diesel
# ...

# %%
k['Price'].value_counts()
# Out:
# Price
# 250000     17
# 350000     14
# 180000     13
# 400000     12
# 130000     12
#            ..
# 749999      1
# 1130000     1
# 1074999     1
# 324999      1
# 500001      1
# Name: count, Length: 273, dtype: int64

# %%
k['Price']=pd.to_numeric(k['Price'],errors='coerce')
k['Price']
# Out:
# C:\Users\rdeva\AppData\Local\Temp\ipykernel_1888\2151417282.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k['Price']=pd.to_numeric(k['Price'],errors='coerce')
# 0       80000
# 1      425000
# 3      325000
# 4      575000
# 6      175000
#         ...
# 887    310000
# 888    260000
# 889    390000
# 890    180000
# 891    160000
# Name: Price, Length: 857, dtype: int64

# %%
k['kms_driven'].value_counts()
# Out:
# kms_driven
# 45,000 kms      30
# 35,000 kms      29
# 55,000 kms      25
# 50,000 kms      23
# 20,000 kms      21
#                 ..
# 1,00,200 kms     1
# 65 kms           1
# 30,874 kms       1
# 1,03,553 kms     1
# 72,160 kms       1
# Name: count, Length: 250, dtype: int64

# %%
k['kms_driven']=k['kms_driven'].astype('str')
k['kms_driven']=k['kms_driven'].str.replace("kms","")
k['kms_driven']
# Out:
# C:\Users\rdeva\AppData\Local\Temp\ipykernel_1888\811538210.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k['kms_driven']=k['kms_driven'].astype('str')
# C:\Users\rdeva\AppData\Local\Temp\ipykernel_1888\811538210.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k['kms_driven']=k['kms_driven'].str.replace("kms","")
# 0      45,000
# 1          40
# 3      28,000
# 4      36,000
# 6      41,000
#         ...
# 887        nan
# 888    27,000
# 889    40,000
# 890     Petrol
# ...

# %%
k['kms_driven']=k['kms_driven'].str.replace(',',"")
k['kms_driven']
# Out:
# C:\Users\rdeva\AppData\Local\Temp\ipykernel_1888\3113148756.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k['kms_driven']=k['kms_driven'].str.replace(',',"")
# 0      45000
# 1         40
# 3      28000
# 4      36000
# 6      41000
#         ...
# 887       nan
# 888    27000
# 889    40000
# 890    Petrol
# 891    Petrol
# Name: kms_driven, Length: 857, dtype: object

# %%
k['kms_driven']=k['kms_driven'].str.replace('Petrol',"")
k['kms_driven']
# Out:
# C:\Users\rdeva\AppData\Local\Temp\ipykernel_1888\3863100518.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k['kms_driven']=k['kms_driven'].str.replace('Petrol',"")
# 0      45000
# 1         40
# 3      28000
# 4      36000
# 6      41000
#         ...
# 887       nan
# 888    27000
# 889    40000
# 890
# 891
# Name: kms_driven, Length: 857, dtype: object

# %%
k['kms_driven'].isnull().value_counts()
# Out:
# kms_driven
# False    857
# Name: count, dtype: int64

# %%
k['kms_driven']=pd.to_numeric(k['kms_driven'],errors='coerce')
k['kms_driven']
# Out:
# C:\Users\rdeva\AppData\Local\Temp\ipykernel_1888\3513955507.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k['kms_driven']=pd.to_numeric(k['kms_driven'],errors='coerce')
# 0      45000.0
# 1         40.0
# 3      28000.0
# 4      36000.0
# 6      41000.0
#         ...
# 887        NaN
# 888    27000.0
# 889    40000.0
# 890        NaN
# 891        NaN
# Name: kms_driven, Length: 857, dtype: float64

# %%
k['kms_driven'].isnull().value_counts()
# Out:
# kms_driven
# False    817
# True      40
# Name: count, dtype: int64

# %%
k['kms_driven'].fillna(k['kms_driven'].mean(),inplace=True)
k['kms_driven']
# Out:
# C:\Users\rdeva\AppData\Local\Temp\ipykernel_1888\991222739.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k['kms_driven'].fillna(k['kms_driven'].mean(),inplace=True)
# 0      45000.00000
# 1         40.00000
# 3      28000.00000
# 4      36000.00000
# 6      41000.00000
#           ...
# 887    46250.71481
# 888    27000.00000
# 889    40000.00000
# 890    46250.71481
# 891    46250.71481
# Name: kms_driven, Length: 857, dtype: float64

# %%
k['kms_driven'].value_counts()
# Out:
# kms_driven
# 46250.71481     40
# 45000.00000     30
# 35000.00000     29
# 55000.00000     25
# 50000.00000     23
#                 ..
# 111111.00000     1
# 25500.00000      1
# 44005.00000      1
# 2110.00000       1
# 132000.00000     1
# Name: count, Length: 248, dtype: int64

# %%
k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 857 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        857 non-null    object
#  1   company     857 non-null    object
#  2   year        857 non-null    object
#  3   Price       857 non-null    int64
#  4   kms_driven  857 non-null    float64
#  5   fuel_type   816 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.9+ KB

# %%
k['year'].unique()
# Out:
# array(['2007', '2006', '2014', '2012', '2013', '2016', '2015', '2010',
#        '2017', '2008', '2018', '2011', '2019', '2009', '2005', '2000',
#        '150k', 'TOUR', '2003', 'r 15', '2004', 'sale', '1995', 'ara)',
#        '2002', 'SELL', '2001', 'tion', 'odel', '2 bs', 'arry', 'o...',
#        'Zest', 'ture', 'emi', 'car', 'able', 'd...', 'SALE', 'sell',
#        'd Ex', 'n...', 'e...', 'go .', 'k...', 'o c4', 'zire', 'Sumo',
#        'cab', 'EV2', 'r...', 'zest'], dtype=object)

# %%
k=k[k['year'].str.isnumeric()]
k
# Out:
#                                        name    company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014  575000
# 6                                 Ford Figo       Ford  2012  175000
# ..                                      ...        ...   ...     ...
# 886                    Toyota Corolla Altis     Toyota  2009  300000
# 888                     Tata Zest XM Diesel       Tata  2018  260000
# 889                      Mahindra Quanto C8   Mahindra  2013  390000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014  180000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014  160000
#
#        kms_driven fuel_type
# 0     45000.00000    Petrol
# 1        40.00000    Diesel
# 3     28000.00000    Petrol
# ...

# %%
k['year'].unique()
# Out:
# array(['2007', '2006', '2014', '2012', '2013', '2016', '2015', '2010',
#        '2017', '2008', '2018', '2011', '2019', '2009', '2005', '2000',
#        '2003', '2004', '1995', '2002', '2001'], dtype=object)

# %%
k['year']=k['year'].astype('int')
k
# Out:
# C:\Users\rdeva\AppData\Local\Temp\ipykernel_1888\2084753860.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k['year']=k['year'].astype('int')
#                                        name    company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014  575000
# 6                                 Ford Figo       Ford  2012  175000
# ..                                      ...        ...   ...     ...
# 886                    Toyota Corolla Altis     Toyota  2009  300000
# ...

# %%
k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 819 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        819 non-null    object
#  1   company     819 non-null    object
#  2   year        819 non-null    int64
#  3   Price       819 non-null    int64
#  4   kms_driven  819 non-null    float64
#  5   fuel_type   816 non-null    object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 44.8+ KB

# %%
d=pd.get_dummies(k['fuel_type'])
d
# Out:
#      Diesel    LPG  Petrol
# 0     False  False    True
# 1      True  False   False
# 3     False  False    True
# 4      True  False   False
# 6      True  False   False
# ..      ...    ...     ...
# 886   False  False    True
# 888    True  False   False
# 889    True  False   False
# 890   False  False   False
# 891   False  False   False
#
# [819 rows x 3 columns]

# %%
k=pd.concat([k,d],axis=1)
k
# Out:
#                                        name    company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014  575000
# 6                                 Ford Figo       Ford  2012  175000
# ..                                      ...        ...   ...     ...
# 886                    Toyota Corolla Altis     Toyota  2009  300000
# 888                     Tata Zest XM Diesel       Tata  2018  260000
# 889                      Mahindra Quanto C8   Mahindra  2013  390000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014  180000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014  160000
#
#        kms_driven fuel_type  Diesel    LPG  Petrol
# 0     45000.00000    Petrol   False  False    True
# ...

# %%
k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 819 entries, 0 to 891
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        819 non-null    object
#  1   company     819 non-null    object
#  2   year        819 non-null    int64
#  3   Price       819 non-null    int64
#  4   kms_driven  819 non-null    float64
#  5   fuel_type   816 non-null    object
#  6   Diesel      819 non-null    bool
#  7   LPG         819 non-null    bool
#  8   Petrol      819 non-null    bool
# dtypes: bool(3), float64(1), int64(2), object(3)
# memory usage: 47.2+ KB

# %%
k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 819 entries, 0 to 891
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        819 non-null    object
#  1   company     819 non-null    object
#  2   year        819 non-null    int64
#  3   Price       819 non-null    int64
#  4   kms_driven  819 non-null    float64
#  5   fuel_type   816 non-null    object
#  6   Diesel      819 non-null    bool
#  7   LPG         819 non-null    bool
#  8   Petrol      819 non-null    bool
# dtypes: bool(3), float64(1), int64(2), object(3)
# memory usage: 47.2+ KB

# %%
k['Price'].mean()
# Out:
# np.float64(410960.40781440784)

# %%
k['Price'].median()
# Out:
# 299999.0

# %%
k['Price'].std()
# Out:
# 474486.55635755765

# %%
k['Price'].var()
# Out:
# 225137492164.0537

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(k['Price'],color='blue')
plt.show()

# %%
k['Price'].kurt()
# Out:
# np.float64(106.9052207246824)

# %%
import seaborn as sns
sns.boxplot(k['Price'])
plt.show()

# %%
import numpy as np
marksA=[20,49,56,78,34]
np.mean(marksA)
# Out:
# np.float64(47.4)

# %%
marksB=[26,34,54,21,65]
np.mean(marksB)
# Out:
# np.float64(40.0)

# %%
from scipy.stats import skew

# %%
a=pd.Series(marksA)
a.skew()
# Out:
# np.float64(0.24577268384915943)

# %%
b=pd.Series(marksB)
b.skew()
# Out:
# np.float64(0.5360073510134563)

# %%
sns.histplot(marksA,kde=True)
# Out:
# <Axes: ylabel='Count'>
