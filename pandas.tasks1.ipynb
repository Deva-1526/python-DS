# %%
import pandas as pd

# %%
#load dataset into dtatframe
ds=pd.read_csv("archive (6).zip")
ds
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#display first 10 rows
ds.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
#unique species 
ds['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
#count flowers in each species
ds['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
#avg petal length for each species
ds['petal_length'].mean()
# Out:
# np.float64(3.758666666666666)

# %%
#flower with max sepal length
ds.loc[ds['sepal_length'].idxmax(),'species']
# Out:
# 'virginica'

# %%
#petal with descending
ds.sort_values('petal_width',ascending=False)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 100           6.3          3.3           6.0          2.5  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 114           5.8          2.8           5.1          2.4  virginica
# 140           6.7          3.1           5.6          2.4  virginica
# ..            ...          ...           ...          ...        ...
# 13            4.3          3.0           1.1          0.1     setosa
# 37            4.9          3.1           1.5          0.1     setosa
# 32            5.2          4.1           1.5          0.1     setosa
# 34            4.9          3.1           1.5          0.1     setosa
# 9             4.9          3.1           1.5          0.1     setosa
#
# [150 rows x 5 columns]

# %%
#flowers with petal_length>5
ds[ds['petal_length']>5]['species']
# Out:
# 83     versicolor
# 100     virginica
# 101     virginica
# 102     virginica
# 103     virginica
# 104     virginica
# 105     virginica
# 107     virginica
# 108     virginica
# 109     virginica
# 110     virginica
# 111     virginica
# 112     virginica
# 114     virginica
# 115     virginica
# 116     virginica
# 117     virginica
# 118     virginica
# 120     virginica
# 122     virginica
# 124     virginica
# 125     virginica
# 128     virginica
# 129     virginica
# 130     virginica
# 131     virginica
# 132     virginica
# 133     virginica
# 134     virginica
# 135     virginica
# 136     virginica
# 137     virginica
# 139     virginica
# 140     virginica
# 141     virginica
# 142     virginica
# 143     virginica
# 144     virginica
# 145     virginica
# 147     virginica
# 148     virginica
# 149     virginica
# Name: species, dtype: object

# %%
#add a new column
ds['total_size']=ds['sepal_length']+ds['petal_length']

# %%
ds.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species',
#        'total_size'],
#       dtype='object')

# %%
#convert petal length column to numpy array
pl=ds['petal_length'].to_numpy()

# %%
type(pl)
# Out:
# numpy.ndarray

# %%
pl.mean()
# Out:
# np.float64(3.758666666666666)

# %%
ds['petal_length'].median()
# Out:
# 4.35

# %%
pl.std()
# Out:
# np.float64(1.7585291834055212)

# %%
pl.max()
# Out:
# np.float64(6.9)

# %%
pl.min()
# Out:
# np.float64(1.0)

# %%
ds['petal_length'].value_counts(normalize=True)
# Out:
# petal_length
# 1.5    0.093333
# 1.4    0.080000
# 5.1    0.053333
# 4.5    0.053333
# 1.6    0.046667
# 1.3    0.046667
# 5.6    0.040000
# 4.7    0.033333
# 4.9    0.033333
# 4.0    0.033333
# 4.2    0.026667
# 5.0    0.026667
# 4.4    0.026667
# 4.8    0.026667
# 1.7    0.026667
# 3.9    0.020000
# 4.6    0.020000
# 5.7    0.020000
# 4.1    0.020000
# 5.5    0.020000
# 6.1    0.020000
# 5.8    0.020000
# 3.3    0.013333
# 5.4    0.013333
# 6.7    0.013333
# 5.3    0.013333
# 5.9    0.013333
# 6.0    0.013333
# 1.2    0.013333
# 4.3    0.013333
# 1.9    0.013333
# 3.5    0.013333
# 5.2    0.013333
# 3.0    0.006667
# 1.1    0.006667
# 3.7    0.006667
# 3.8    0.006667
# 6.6    0.006667
# 6.3    0.006667
# 1.0    0.006667
# 6.9    0.006667
# 3.6    0.006667
# 6.4    0.006667
# Name: proportion, dtype: float64

# %%
import pandas as pd

# %%
df=pd.read_csv("netflix_titles.csv (1).zip")
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
df[df['type']=='Movie'].shape[0]
# Out:
# 6131

# %%
df[df['release_year']>2020]['title' ]
# Out:
# 1                   Blood & Water
# 2                       Ganglands
# 3           Jailbirds New Orleans
# 4                    Kota Factory
# 5                   Midnight Mass
#                   ...
# 1468    What Happened to Mr. Cha?
# 1551                        Hilda
# 1696                 Polly Pocket
# 2920                Love Is Blind
# 8437       The Netflix Afterparty
# Name: title, Length: 592, dtype: object

# %%
df.loc[df['release_year'].idxmin(), 'title']
# Out:
# 'Pioneers: First Women Filmmakers*'

# %%
df[df['type']=='Movie']['country'].value_counts()
# Out:
# country
# United States                            2058
# India                                     893
# United Kingdom                            206
# Canada                                    122
# Spain                                      97
#                                          ...
# United Kingdom, Russia, United States       1
# Paraguay, Argentina                         1
# United Kingdom, Malawi                      1
# Austria, Iraq, United States                1
# United Arab Emirates, Jordan                1
# Name: count, Length: 651, dtype: int64

# %%
df['director'].value_counts().head(10)
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: count, dtype: int64

# %%
df['director'].head()
# Out:
# 0    Kirsten Johnson
# 1                NaN
# 2    Julien Leclercq
# 3                NaN
# 4                NaN
# Name: director, dtype: object

# %%
df[df['type']=='Movie']['duration']
# Out:
# 0        90 min
# 6        91 min
# 7       125 min
# 9       104 min
# 12      127 min
#          ...
# 8801     96 min
# 8802    158 min
# 8804     88 min
# 8805     88 min
# 8806    111 min
# Name: duration, Length: 6131, dtype: object

# %%
df.loc[df['duration'].str.extract('(\d+)').astype(float).idxmax(),'title']
# Out:
# 4253    Black Mirror: Bandersnatch
# Name: title, dtype: object

# %%
df=pd.read_csv("netflix_titles.csv (1).zip")
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df=df.drop(['show_id','date_added','rating','description'],axis="columns",errors='ignore')
df
# Out:
#          type                  title         director  \
# 0       Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1     TV Show          Blood & Water              NaN
# 2     TV Show              Ganglands  Julien Leclercq
# 3     TV Show  Jailbirds New Orleans              NaN
# 4     TV Show           Kota Factory              NaN
# ...       ...                    ...              ...
# 8802    Movie                 Zodiac    David Fincher
# 8803  TV Show            Zombie Dumb              NaN
# 8804    Movie             Zombieland  Ruben Fleischer
# 8805    Movie                   Zoom     Peter Hewitt
# 8806    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# ...

# %%
df[df['type']== 'Movie'].sort_values('release_year')
# Out:
#        type                                          title  \
# 7790  Movie                                 Prelude to War
# 8205  Movie                           The Battle of Midway
# 8660  Movie  Undercover: How to Operate Behind Enemy Lines
# 8763  Movie                WWII: Report from the Aleutians
# 8739  Movie             Why We Fight: The Battle of Russia
# ...     ...                                            ...
# 1420  Movie        Crack: Cocaine, Corruption & Conspiracy
# 373   Movie                             The Last Mercenary
# 1424  Movie                                       Charming
# 372   Movie                 Rurouni Kenshin: The Beginning
# 394   Movie                                African America
#
#                          director  \
# 7790                  Frank Capra
# 8205                    John Ford
# 8660                    John Ford
# 8763                  John Huston
# 8739  Frank Capra, Anatole Litvak
# ...                           ...
# ...

# %%
df[df['listed_in'].str.contains('Comedy',na=False)]
# Out:
#          type                                              title  \
# 278     Movie                        Lokillo: Nothing's the Same
# 359     Movie                       The Original Kings of Comedy
# 388   TV Show            Plastic Cup Boyz: Laughing My Mask Off!
# 400   TV Show  Revelations: The Masters of the Universe: Reve...
# 475     Movie                                       The Stand-Up
# ...       ...                                                ...
# 7812  TV Show                                   Queens of Comedy
# 7813  TV Show                                   Queens vs. Kings
# 7908  TV Show                       Russell Peters vs. the World
# 7909    Movie                          Russell Peters: Notorious
# 8437  TV Show                             The Netflix Afterparty
#
#                              director  \
# 278                    Julián Gaviria
# 359                         Spike Lee
# 388   Royale Watkins, Rich Schlansker
# ...

# %%
df['decade']=(df['release_year']//10)*10
df
# Out:
#          type                  title         director  \
# 0       Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1     TV Show          Blood & Water              NaN
# 2     TV Show              Ganglands  Julien Leclercq
# 3     TV Show  Jailbirds New Orleans              NaN
# 4     TV Show           Kota Factory              NaN
# ...       ...                    ...              ...
# 8802    Movie                 Zodiac    David Fincher
# 8803  TV Show            Zombie Dumb              NaN
# 8804    Movie             Zombieland  Ruben Fleischer
# 8805    Movie                   Zoom     Peter Hewitt
# 8806    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# ...

# %%
du=df['duration'].to_numpy()

# %%
type(du)
# Out:
# numpy.ndarray
